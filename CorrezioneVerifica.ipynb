# %%
import random
#1. Popolamento statico iniziale:
dizionario = {
    "Mario Rossi" : [((8, 7, 9), "Junior Chef"), ((7, 8, 8), "Junior Chef"), ((9, 9, 8), "Junior Chef"), ((8, 8, 9), "Junior Chef")],
    "Luigi Bianchi" : [((7, 7, 8), "Senior Chef"), ((8, 9, 7), "Senior Chef"), ((7, 8, 7), "Senior Chef"), ((9, 8, 8), "Senior Chef")],
    "Giulia Verdi" : [((9, 8, 8), "Junior Chef"), ((8, 7, 9), "Junior Chef"), ((8, 8, 8), "Junior Chef"), ((7, 9, 8), "Junior Chef")],
}

listaCategoriaPiatti = ["Antipasti", "Primi", "Secondi", "Dessert", "Piatti unici"] # Dichiaro le varie categorie
print("Ecco il dizionario di base: ")
print(dizionario)

#2. Aggiunta statica di un nuovo chef:
dizionario["Davide Beolchi"] = [((8, 7, 9), "Junior Chef"), ((7, 3, 8), "Junior Chef"), ((9, 9, 8), "Junior Chef"), ((8, 8, 9), "Junior Chef")]

print()
print("Ecco il dizionario aggiornato dopo l'aggiunta statica di un nuovo chef:")
print(dizionario)

#3. Funzione per l'aggiunta di una nuova categoria di piatto:
def funzioneAggiuntaCetegoria():
  for chef in dizionario.keys():
    for valori, categoria in dizionario[chef]:
      creatività = random.randint(1,10)
      gusto = random.randint(1,10)
      presentazione = random.randint(1,10)
      dizionario[chef].append(((creatività, gusto, presentazione), categoria))
      break

print()
print("Ecco il dizionario dopo la funzione 'aggiunta nuova categoria di piatto: ")
funzioneAggiuntaCetegoria()
print(dizionario)

#4. Funzione per la stampa dati di uno chef :
def mostraChef(nomeChef):
    print(f"Ecco i dati dello chef {nomeChef}:")
    i = 0
    for dati in dizionario[nomeChef]:
        valori, categoria = dati
        (punteggi1, punteggi2, punteggi3) = valori
        print()
        print(f"Categoria {listaCategoriaPiatti[i]}: ")
        print(f"Categoria di chef: {categoria}")
        print(f"Punteggi antipasti :{punteggi1}")
        print(f"creatività: {punteggi2}")
        print(f"Gusto: {punteggi3}")
    i += 1

print()
print("Funzione stampa dati di uno chef: ")
nomeChef = input("Inserisci il nome dello chef: ")
if(nomeChef not in dizionario):
    print("Errore! Chef non presente.")
else:
    mostraChef(nomeChef)

#5. Funzione per la stampa dati di un piatto:
def stampaPiatto(categoriaPiatti, categoriaPiattiPosizione):
  i = 0
  for chef in dizionario.keys():
    for valori, categoria in dizionario[chef]:
      (punteggi1, punteggi2, punteggi3) = valori
      if(i == categoriaPiattiPosizione):
        print(f"Informazioni sulla categoria piatti '{categoriaPiatti}' per {chef}: ")
        print(f"Categoria di chef: {categoria}")
        print(f"Punteggi antipasti :{punteggi1}")
        print(f"creatività: {punteggi2}")
        print(f"Gusto: {punteggi3}")
        break
      i += 1

print()
print("Funzione per la stampa di un piatto: ")
categoriaPiatti = input("Inserisci la categoria dei piatti: ")
if(categoriaPiatti not in listaCategoriaPiatti):
    print("Errore! Categoria non presente.")
else:
    if(categoriaPiatti == "Antipasti"):
        categoriaPiattiPosizione = 0
    elif(categoriaPiatti == "Primi"):
        categoriaPiattiPosizione = 1
    elif(categoriaPiatti == "Secondi"):
        categoriaPiattiPosizione = 2
    elif(categoriaPiatti == "Dessert"):
        categoriaPiattiPosizione = 3
    elif(categoriaPiatti == "Piatti unici"):
        categoriaPiattiPosizione = 4
    stampaPiatto(categoriaPiatti, categoriaPiattiPosizione)

#6. Funzione per l'analisi dei punteggi:
print()
print("Funzione per l'analisi dei punteggi: ")

def funzioneStampaPunteggioTotalemassimo(dizionario, categoriaPiattiPosizione):
  for chef in dizionario:
    valori, categoria = dizionario[chef][categoriaPiattiPosizione]
  maxValore = max(valori)
  return maxValore

categoriaPiatti = input("Inserisci la categoria dei piatti: ")
if(categoriaPiatti not in listaCategoriaPiatti):
    print("Errore! Categoria non presente.")
else:
    if(categoriaPiatti == "Antipasti"):
        categoriaPiattiPosizione = 0
    elif(categoriaPiatti == "Primi"):
        categoriaPiattiPosizione = 1
    elif(categoriaPiatti == "Secondi"):
        categoriaPiattiPosizione = 2
    elif(categoriaPiatti == "Dessert"):
        categoriaPiattiPosizione = 3
    elif(categoriaPiatti == "Piatti unici"):
        categoriaPiattiPosizione = 4
    funzioneStampaPunteggioTotalemassimo(dizionario, categoriaPiattiPosizione)
    print(f"Valore max: {funzioneStampaPunteggioTotalemassimo(dizionario, categoriaPiattiPosizione)}")

#7. Funzione per l'aggiunta di un nuovo chef:
print()
print("Funzione per l'aggiunta di un nuovo chef: ")
def inserisci_nuovo_chef(dizionario, nominativo, risultati):
    dizionario[nominativo] = risultati

def inserisci_dati_nuovo_chef():
    listaRisultati = []
    i = 0
    nome = input("Inserisci il nome: ")
    cognome = input("Inserisci il cognome: ")
    nomeCognome = nome +" "+ cognome
    if(nomeCognome in dizionario):
        print("Nome già presente! ")
    else:
        while(len(listaCategoriaPiatti) > i):
            print(f"Categoria {listaCategoriaPiatti[i]}: ")
            punteggio1 = input("Inserisci il punteggio 1:")
            punteggio2 = input("Inserisci il punteggio 2:")
            punteggio3 = input("Inserisci il punteggio 3:")

            categoria = input("Inserisci la categoria: ")
            tupla = ((punteggio1, punteggio2, punteggio3), categoria)
            listaRisultati.append(tupla)
            i += 1

    return nomeCognome, listaRisultati
nominativo, risultati = inserisci_dati_nuovo_chef()
inserisci_nuovo_chef(dizionario, nominativo, risultati)
print(dizionario)
# Out:
# Ecco il dizionario di base:
# {'Mario Rossi': [((8, 7, 9), 'Junior Chef'), ((7, 8, 8), 'Junior Chef'), ((9, 9, 8), 'Junior Chef'), ((8, 8, 9), 'Junior Chef')], 'Luigi Bianchi': [((7, 7, 8), 'Senior Chef'), ((8, 9, 7), 'Senior Chef'), ((7, 8, 7), 'Senior Chef'), ((9, 8, 8), 'Senior Chef')], 'Giulia Verdi': [((9, 8, 8), 'Junior Chef'), ((8, 7, 9), 'Junior Chef'), ((8, 8, 8), 'Junior Chef'), ((7, 9, 8), 'Junior Chef')]}
#
# Ecco il dizionario aggiornato dopo l'aggiunta statica di un nuovo chef:
# {'Mario Rossi': [((8, 7, 9), 'Junior Chef'), ((7, 8, 8), 'Junior Chef'), ((9, 9, 8), 'Junior Chef'), ((8, 8, 9), 'Junior Chef')], 'Luigi Bianchi': [((7, 7, 8), 'Senior Chef'), ((8, 9, 7), 'Senior Chef'), ((7, 8, 7), 'Senior Chef'), ((9, 8, 8), 'Senior Chef')], 'Giulia Verdi': [((9, 8, 8), 'Junior Chef'), ((8, 7, 9), 'Junior Chef'), ((8, 8, 8), 'Junior Chef'), ((7, 9, 8), 'Junior Chef')], 'Davide Beolchi': [((8, 7, 9), 'Junior Chef'), ((7, 3, 8), 'Junior Chef'), ((9, 9, 8), 'Junior Chef'), ((8, 8, 9), 'Junior Chef')]}
#
# Ecco il dizionario dopo la funzione 'aggiunta nuova categoria di piatto:
# {'Mario Rossi': [((8, 7, 9), 'Junior Chef'), ((7, 8, 8), 'Junior Chef'), ((9, 9, 8), 'Junior Chef'), ((8, 8, 9), 'Junior Chef'), ((9, 9, 8), 'Junior Chef')], 'Luigi Bianchi': [((7, 7, 8), 'Senior Chef'), ((8, 9, 7), 'Senior Chef'), ((7, 8, 7), 'Senior Chef'), ((9, 8, 8), 'Senior Chef'), ((7, 8, 6), 'Senior Chef')], 'Giulia Verdi': [((9, 8, 8), 'Junior Chef'), ((8, 7, 9), 'Junior Chef'), ((8, 8, 8), 'Junior Chef'), ((7, 9, 8), 'Junior Chef'), ((9, 8, 2), 'Junior Chef')], 'Davide Beolchi': [((8, 7, 9), 'Junior Chef'), ((7, 3, 8), 'Junior Chef'), ((9, 9, 8), 'Junior Chef'), ((8, 8, 9), 'Junior Chef'), ((1, 9, 8), 'Junior Chef')]}
#
# Funzione stampa dati di uno chef:
# Inserisci il nome dello chef: Mario Rossi
# Ecco i dati dello chef Mario Rossi:
#
# Categoria Antipasti:
# Categoria di chef: Junior Chef
# Punteggi antipasti :8
# creatività: 7
# Gusto: 9
#
# Categoria Antipasti:
# Categoria di chef: Junior Chef
# Punteggi antipasti :7
# creatività: 8
# Gusto: 8
#
# Categoria Antipasti:
# Categoria di chef: Junior Chef
# Punteggi antipasti :9
# creatività: 9
# Gusto: 8
#
# Categoria Antipasti:
# Categoria di chef: Junior Chef
# Punteggi antipasti :8
# creatività: 8
# Gusto: 9
#
# Categoria Antipasti:
# Categoria di chef: Junior Chef
# Punteggi antipasti :9
# creatività: 9
# Gusto: 8
#
# Funzione per la stampa di un piatto:
# Inserisci la categoria dei piatti: Antipasti
# Informazioni sulla categoria piatti 'Antipasti' per Mario Rossi:
# Categoria di chef: Junior Chef
# Punteggi antipasti :8
# creatività: 7
# Gusto: 9
# Informazioni sulla categoria piatti 'Antipasti' per Luigi Bianchi:
# Categoria di chef: Senior Chef
# Punteggi antipasti :7
# creatività: 7
# Gusto: 8
# Informazioni sulla categoria piatti 'Antipasti' per Giulia Verdi:
# Categoria di chef: Junior Chef
# Punteggi antipasti :9
# creatività: 8
# Gusto: 8
# Informazioni sulla categoria piatti 'Antipasti' per Davide Beolchi:
# Categoria di chef: Junior Chef
# Punteggi antipasti :8
# creatività: 7
# Gusto: 9
#
# Funzione per l'analisi dei punteggi:
# Inserisci la categoria dei piatti: Antipasti
# Valore max: 9
# Inserisci il nome: Davi
# Inserisci il cognome: De
# Categoria Antipasti:
# Inserisci il punteggio 1:12
# Inserisci il punteggio 2:3
# Inserisci il punteggio 3:4
# Inserisci la categoria: jd
# Categoria Primi:
# Inserisci il punteggio 1:12
# Inserisci il punteggio 2:3
# Inserisci il punteggio 3:4
# Inserisci la categoria: g
# Categoria Secondi:
# Inserisci il punteggio 1:123
# Inserisci il punteggio 2:4
# Inserisci il punteggio 3:5
# Inserisci la categoria: g
# Categoria Dessert:
# Inserisci il punteggio 1:1
# Inserisci il punteggio 2:3
# Inserisci il punteggio 3:4
# Inserisci la categoria: g
# Categoria Piatti unici:
# Inserisci il punteggio 1:32
# Inserisci il punteggio 2:4
# Inserisci il punteggio 3:5
# Inserisci la categoria: h
